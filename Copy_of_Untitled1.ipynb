# %% [markdown]
# <a href="https://colab.research.google.com/github/TheProgenitorofTheTrueEmpire/Apple-site/blob/main/Copy_of_Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import cv2

# %%
image = cv2 . imread("amir.png")

# %%
plt .imshow(image)

# %%
image = cv2.cvtColor(image , cv2.COLOR_BGR2RGB)

# %%
model = cv2 . CascadeClassifier ("model.xml")

# %%
sort = model . detectMultiScale(image)

# %%
print(sort)
# Out:
# [[462 231 388 388]]

# %%
image = cv2.rectangle( image ,(x , y) , (x+a,y+b) , (0,250,0), 5 )

# %%
x =sort [0][0]

# %%
y =sort[0][1]
a =sort[0][2]
b =sort[0][3]
